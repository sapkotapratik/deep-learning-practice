# %% [markdown]
# # Neural Ordinary Differential Equationsm

# %% [markdown]
# ### We group these network in discrete layers
# ![image.png](attachment:image.png)
# ### Let us consider NN as continuous function that is infintesmally big/small
# - In this idea, instead of specifying the number beforehand we specify the desired accuracy and it will learn how to train itself within that margin of error.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Why does this matter?
# - Faster testing time than recurrent networks, but slow tra
